# %% [markdown]
# # Banking Transactions

# %%
# !pip install fg-data-profiling numpy pandas matplotlib seaborn --quiet

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import data_profiling
from data_profiling import ProfileReport

# %%
import os

# %% [markdown]
# ### Load Data

# %%
accounts = pd.read_csv(r'D:\archive\Datasets\accounts.csv')

branches = pd.read_csv(r'D:\archive\Datasets\branches.csv')

card_transactions = pd.read_csv(r'D:\archive\Datasets\card_transactions.csv')

cards = pd.read_csv(r'D:\archive\Datasets\cards.csv')

customers = pd.read_csv(r'D:\archive\Datasets\customers.csv')

emp = pd.read_csv(r'D:\archive\Datasets\employees.csv')

loan_payments = pd.read_csv(r'D:\archive\Datasets\loan_payments.csv')

loans = pd.read_csv(r'D:\archive\Datasets\loans.csv')

support = pd.read_csv(r'D:\archive\Datasets\support_tickets.csv')

transactions = pd.read_csv(r'D:\archive\Datasets\transactions.csv')

# %%
datasets = {
    'accounts' : accounts,
    'branches' : branches,
    'card_transactions' : card_transactions,
    'cards' : cards,
    'customers' : customers,
    'emp' : emp,
    'loan_payments' : loan_payments,
    'loans' : loans,
    'support' : support,
    'transactions' : transactions
}

# Generate Report for each data
for name, df in datasets.items():
    profile = ProfileReport(df, title = f'{name.title()} Report')
    profile.to_file(f'{name}_report.html')

print('All Reports Generated Successfully')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# All Reports Generated Successfully

# %%
# It shows the, where your reports are saved in your system
import os

print(os.getcwd())
# Out:
# C:\Users\JAYA KRISHNA

# %% [markdown]
# ### Accounrs Data

# %%
accounts
# Out:
#        account_id  customer_id  branch_id   account_type    balance  \
# 0               1        11749        141        Current   95902.00
# 1               2        47716         43        Current   13261.61
# 2               3        56143         90        Savings   26495.92
# 3               4        29193        113         Salary   74682.72
# 4               5        49907         28        Current   40419.01
# ...           ...          ...        ...            ...        ...
# 94995       94996        43366         38  Fixed Deposit   66228.51
# 94996       94997        50856         12        Current   39854.55
# 94997       94998         8593         68        Current    9310.24
# 94998       94999        49233        107  Fixed Deposit   13110.16
# 94999       95000        53515         34        Savings  221443.76
#
#         open_date  status
# 0      2019-10-20  Active
# 1      2026-02-03  Active
# 2      2020-10-19  Active
# 3      2012-02-22  Active
# ...

# %%
accounts['account_id'].unique()
# Out:
# array([    1,     2,     3, ..., 94998, 94999, 95000], shape=(95000,))

# %%
accounts['account_id'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 94995    False
# 94996    False
# 94997    False
# 94998    False
# 94999    False
# Name: account_id, Length: 95000, dtype: bool

# %%
accounts.describe()
# Out:
#          account_id   customer_id     branch_id        balance
# count  95000.000000  95000.000000  95000.000000   95000.000000
# mean   47500.500000  29991.208179     75.450695   45761.236422
# std    27424.282124  17264.584944     43.295402   45306.411751
# min        1.000000      1.000000      1.000000     500.360000
# 25%    23750.750000  15114.750000     38.000000   13551.047500
# 50%    47500.500000  30000.000000     75.000000   31768.655000
# 75%    71250.250000  44910.000000    113.000000   63337.515000
# max    95000.000000  60000.000000    150.000000  539198.590000

# %%
accounts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95000 entries, 0 to 94999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   account_id    95000 non-null  int64
#  1   customer_id   95000 non-null  int64
#  2   branch_id     95000 non-null  int64
#  3   account_type  95000 non-null  object
#  4   balance       95000 non-null  float64
#  5   open_date     95000 non-null  object
#  6   status        95000 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 5.1+ MB

# %%
accounts.shape
# Out:
# (95000, 7)

# %%
# Missing Values
accounts.isnull().sum()
# Out:
# account_id      0
# customer_id     0
# branch_id       0
# account_type    0
# balance         0
# open_date       0
# status          0
# dtype: int64

# %%
accounts.index
# Out:
# RangeIndex(start=0, stop=95000, step=1)

# %%
accounts.set_index('account_id', inplace=True)

# %%
accounts
# Out:
#             customer_id  branch_id   account_type    balance   open_date  \
# account_id
# 1                 11749        141        Current   95902.00  2019-10-20
# 2                 47716         43        Current   13261.61  2026-02-03
# 3                 56143         90        Savings   26495.92  2020-10-19
# 4                 29193        113         Salary   74682.72  2012-02-22
# 5                 49907         28        Current   40419.01  2007-01-03
# ...                 ...        ...            ...        ...         ...
# 94996             43366         38  Fixed Deposit   66228.51  2012-03-18
# 94997             50856         12        Current   39854.55  2011-10-21
# 94998              8593         68        Current    9310.24  2021-03-22
# 94999             49233        107  Fixed Deposit   13110.16  2009-10-16
# 95000             53515         34        Savings  221443.76  2025-08-11
#
#             status
# account_id
# 1           Active
# 2           Active
# ...

# %%
accounts['open_date'] = pd.to_datetime(accounts['open_date'], format="mixed")

# %%
accounts
# Out:
#             customer_id  branch_id   account_type    balance  open_date  \
# account_id
# 1                 11749        141        Current   95902.00 2019-10-20
# 2                 47716         43        Current   13261.61 2026-02-03
# 3                 56143         90        Savings   26495.92 2020-10-19
# 4                 29193        113         Salary   74682.72 2012-02-22
# 5                 49907         28        Current   40419.01 2007-01-03
# ...                 ...        ...            ...        ...        ...
# 94996             43366         38  Fixed Deposit   66228.51 2012-03-18
# 94997             50856         12        Current   39854.55 2011-10-21
# 94998              8593         68        Current    9310.24 2021-03-22
# 94999             49233        107  Fixed Deposit   13110.16 2009-10-16
# 95000             53515         34        Savings  221443.76 2025-08-11
#
#             status
# account_id
# 1           Active
# 2           Active
# ...

# %%
branches
# Out:
#      branch_id         branch_name       city           state opened_date  \
# 0            1       Pune Branch 1       Pune     Maharashtra  2016-05-23
# 1            2     Bhopal Branch 2     Bhopal  Madhya Pradesh  2002-01-13
# 2            3    Lucknow Branch 3    Lucknow   Uttar Pradesh  2017-12-10
# 3            4    Kolkata Branch 4    Kolkata     West Bengal  2002-05-04
# 4            5    Kolkata Branch 5    Kolkata     West Bengal  2005-11-09
# ..         ...                 ...        ...             ...         ...
# 145        146      Kochi Branch 2      Kochi          Kerala  2017-05-27
# 146        147     Mumbai Branch 3     Mumbai     Maharashtra  2008-07-27
# 147        148  Bengaluru Branch 4  Bengaluru       Karnataka  1998-07-04
# 148        149      Kochi Branch 5      Kochi          Kerala  2002-07-22
# 149        150     Mumbai Branch 6     Mumbai     Maharashtra  2008-11-06
#
#       ifsc_code
# 0    BNK0000000
# 1    BNK0000001
# 2    BNK0000002
# ...

# %%
branches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   branch_id    150 non-null    int64
#  1   branch_name  150 non-null    object
#  2   city         150 non-null    object
#  3   state        150 non-null    object
#  4   opened_date  150 non-null    object
#  5   ifsc_code    150 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 7.2+ KB

# %%
branches['opened_date'] = pd.to_datetime(branches['opened_date'], format = 'mixed')

# %%
branches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   branch_id    150 non-null    int64
#  1   branch_name  150 non-null    object
#  2   city         150 non-null    object
#  3   state        150 non-null    object
#  4   opened_date  150 non-null    datetime64[ns]
#  5   ifsc_code    150 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 7.2+ KB

# %%
branches.isnull().sum()
# Out:
# branch_id      0
# branch_name    0
# city           0
# state          0
# opened_date    0
# ifsc_code      0
# dtype: int64

# %%
branches['year'] = branches['opened_date'].dt.year

# %%
branches['month'] = branches['opened_date'].dt.month_name()

# %%
branches.columns
# Out:
# Index(['branch_id', 'branch_name', 'city', 'state', 'opened_date', 'ifsc_code',
#        'year', 'month'],
#       dtype='object')

# %%
branches.head()
# Out:
#    branch_id       branch_name     city           state opened_date  \
# 0          1     Pune Branch 1     Pune     Maharashtra  2016-05-23
# 1          2   Bhopal Branch 2   Bhopal  Madhya Pradesh  2002-01-13
# 2          3  Lucknow Branch 3  Lucknow   Uttar Pradesh  2017-12-10
# 3          4  Kolkata Branch 4  Kolkata     West Bengal  2002-05-04
# 4          5  Kolkata Branch 5  Kolkata     West Bengal  2005-11-09
#
#     ifsc_code  year     month
# 0  BNK0000000  2016       May
# 1  BNK0000001  2002   January
# 2  BNK0000002  2017  December
# 3  BNK0000003  2002       May
# 4  BNK0000004  2005  November

# %%
card_transactions
# Out:
#          card_txn_id  card_id    txn_date merchant_category   amount  is_fraud
# 0                  1    52505  2025-01-28         Education  2162.41         0
# 1                  2    12716  2022-08-26         Education  2236.55         0
# 2                  3    49060  2019-10-07            Travel  1184.59         0
# 3                  4    18295  2019-03-07            Travel   124.79         0
# 4                  5    54342  2026-03-26         Insurance   546.10         0
# ...              ...      ...         ...               ...      ...       ...
# 2999995      2999996    35925  2019-05-02     Entertainment   655.20         0
# 2999996      2999997    23555  2023-01-17          Shopping   775.03         0
# 2999997      2999998    17322  2025-02-10          Shopping   669.16         0
# 2999998      2999999    31765  2018-04-27         Education   449.14         0
# 2999999      3000000    59784  2018-09-15         Education  2524.09         0
#
# ...

# %%
card_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   card_txn_id        int64
#  1   card_id            int64
#  2   txn_date           object
#  3   merchant_category  object
#  4   amount             float64
#  5   is_fraud           int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.3+ MB

# %%
card_transactions.isnull().sum()
# Out:
# card_txn_id          0
# card_id              0
# txn_date             0
# merchant_category    0
# amount               0
# is_fraud             0
# dtype: int64

# %%
card_transactions['is_fraud'].unique()
# Out:
# array([0, 1])

# %%
card_transactions['card_id'].unique()
# Out:
# array([52505, 12716, 49060, ..., 14546, 34167,  3838], shape=(65000,))

# %%
card_transactions['card_txn_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
card_transactions['merchant_category'].unique()
# Out:
# array(['Education', 'Travel', 'Insurance', 'ATM Withdrawal', 'Groceries',
#        'Shopping', 'Rent', 'Fund Transfer', 'Salary Credit', 'Dining',
#        'Utilities', 'Entertainment', 'Healthcare', 'Fuel'], dtype=object)

# %%
card_transactions['txn_date'] = pd.to_datetime(card_transactions['txn_date'], format='mixed')

# %%
card_transactions['year'] = card_transactions['txn_date'].dt.year
card_transactions['month'] = card_transactions['txn_date'].dt.month_name()

# %%
card_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   card_txn_id        int64
#  1   card_id            int64
#  2   txn_date           datetime64[ns]
#  3   merchant_category  object
#  4   amount             float64
#  5   is_fraud           int64
#  6   year               int32
#  7   month              object
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(3), object(2)
# memory usage: 171.7+ MB

# %%
card_transactions.columns
# Out:
# Index(['card_txn_id', 'card_id', 'txn_date', 'merchant_category', 'amount',
#        'is_fraud', 'year', 'month'],
#       dtype='object')

# %%
card_transactions
# Out:
#          card_txn_id  card_id   txn_date merchant_category   amount  is_fraud  \
# 0                  1    52505 2025-01-28         Education  2162.41         0
# 1                  2    12716 2022-08-26         Education  2236.55         0
# 2                  3    49060 2019-10-07            Travel  1184.59         0
# 3                  4    18295 2019-03-07            Travel   124.79         0
# 4                  5    54342 2026-03-26         Insurance   546.10         0
# ...              ...      ...        ...               ...      ...       ...
# 2999995      2999996    35925 2019-05-02     Entertainment   655.20         0
# 2999996      2999997    23555 2023-01-17          Shopping   775.03         0
# 2999997      2999998    17322 2025-02-10          Shopping   669.16         0
# 2999998      2999999    31765 2018-04-27         Education   449.14         0
# 2999999      3000000    59784 2018-09-15         Education  2524.09         0
#
#          year      month
# ...

# %%
cards
# Out:
#        card_id  customer_id  account_id         card_type  issue_date  \
# 0            1        34846       75950     Credit - Gold  2018-12-05
# 1            2        50151       55880  Credit - Classic  2016-05-19
# 2            3        11246       86152     Credit - Gold  2023-08-30
# 3            4        23866       10907  Credit - Classic  2018-07-24
# 4            5        14097       22455  Credit - Classic  2023-08-16
# ...        ...          ...         ...               ...         ...
# 64995    64996        42408       77919             Debit  2017-09-11
# 64996    64997         3333       40802             Debit  2018-01-16
# 64997    64998        16499       59824             Debit  2015-03-22
# 64998    64999        15727       72960     Credit - Gold  2017-10-09
# 64999    65000        16786       60810  Credit - Classic  2021-04-19
#
#       expiry_date  credit_limit   status
# 0      2023-12-04             0   Active
# 1      2021-05-18             0   Active
# ...

# %%
cards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65000 entries, 0 to 64999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   card_id       65000 non-null  int64
#  1   customer_id   65000 non-null  int64
#  2   account_id    65000 non-null  int64
#  3   card_type     65000 non-null  object
#  4   issue_date    65000 non-null  object
#  5   expiry_date   65000 non-null  object
#  6   credit_limit  65000 non-null  int64
#  7   status        65000 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 4.0+ MB

# %%
cards['card_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
cards['customer_id'].duplicated().sum()
# Out:
# np.int64(25373)

# %%
# To display duplicated records
cards[cards.duplicated(subset=['customer_id'])]
# Out:
#        card_id  customer_id  account_id          card_type  issue_date  \
# 256        257        52916       42003              Debit  2019-04-30
# 394        395        18281       70791              Debit  2021-04-09
# 520        521        29791        8942              Debit  2016-06-25
# 814        815        11710       84462              Debit  2016-07-21
# 913        914        26295       10595              Debit  2019-10-03
# ...        ...          ...         ...                ...         ...
# 64994    64995         8974       56146  Credit - Platinum  2022-10-17
# 64995    64996        42408       77919              Debit  2017-09-11
# 64996    64997         3333       40802              Debit  2018-01-16
# 64998    64999        15727       72960      Credit - Gold  2017-10-09
# 64999    65000        16786       60810   Credit - Classic  2021-04-19
#
#       expiry_date  credit_limit   status
# 256    2024-04-28             0   Active
# ...

# %%
cards['issue_date'] = pd.to_datetime(cards['issue_date'])

# %%
cards['expiry_date'] = pd.to_datetime(cards['expiry_date'])

# %%
cards.isnull().sum()
# Out:
# card_id         0
# customer_id     0
# account_id      0
# card_type       0
# issue_date      0
# expiry_date     0
# credit_limit    0
# status          0
# dtype: int64

# %%
cards['status'].unique()
# Out:
# array(['Active', 'Expired', 'Blocked'], dtype=object)

# %%
cards['credit_limit'].unique()
# Out:
# array([     0,  50000,  25000, 200000, 500000, 100000])

# %%
(cards['status'] == 'Active').sum()
# Out:
# np.int64(57214)

# %%
(cards['status'] == 'Expired').sum()
# Out:
# np.int64(3336)

# %%
(cards['status'] == 'Blocked').sum()
# Out:
# np.int64(4450)

# %%
(cards['credit_limit'] == 0).sum()
# Out:
# np.int64(35684)

# %%
(cards['credit_limit'] == 50000).sum()
# Out:
# np.int64(9741)

# %%
(cards['credit_limit'] == 25000).sum()
# Out:
# np.int64(9848)

# %%
(cards['credit_limit'] == 200000).sum()
# Out:
# np.int64(3326)

# %%
(cards['credit_limit'] == 500000).sum()
# Out:
# np.int64(1340)

# %%
(cards['credit_limit'] == 100000).sum()
# Out:
# np.int64(5061)

# %%
cards[cards['credit_limit'] == 0].head(10)
# Out:
#     card_id  customer_id  account_id         card_type issue_date expiry_date  \
# 0         1        34846       75950     Credit - Gold 2018-12-05  2023-12-04
# 1         2        50151       55880  Credit - Classic 2016-05-19  2021-05-18
# 3         4        23866       10907  Credit - Classic 2018-07-24  2023-07-23
# 8         9        15781       83286             Debit 2015-10-02  2020-09-30
# 9        10         3471        1938  Credit - Classic 2020-02-10  2025-02-08
# 11       12        56703        8466             Debit 2018-12-06  2023-12-05
# 14       15        25499       38174  Credit - Classic 2022-03-01  2027-02-28
# 15       16         2927        1350             Debit 2018-07-17  2023-07-16
# 16       17        14980       71392     Credit - Gold 2015-07-04  2020-07-02
# 17       18         5469       18127  Credit - Classic 2017-10-08  2022-10-07
#
#     credit_limit   status
# 0              0   Active
# 1              0   Active
# 3              0   Active
# ...

# %%
cards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65000 entries, 0 to 64999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   card_id       65000 non-null  int64
#  1   customer_id   65000 non-null  int64
#  2   account_id    65000 non-null  int64
#  3   card_type     65000 non-null  object
#  4   issue_date    65000 non-null  datetime64[ns]
#  5   expiry_date   65000 non-null  datetime64[ns]
#  6   credit_limit  65000 non-null  int64
#  7   status        65000 non-null  object
# dtypes: datetime64[ns](2), int64(4), object(2)
# memory usage: 4.0+ MB

# %%
customers.head(10)
# Out:
#    customer_id               name  gender date_of_birth        city  \
# 0            1       Pooja Garcia    Male    1987-12-11   Ahmedabad
# 1            2      Anjali Kapoor  Female    1965-12-18     Lucknow
# 2            3        James Smith  Female    1979-03-12  Chandigarh
# 3            4        Susan Joshi    Male    1996-11-07      Nagpur
# 4            5        Kiran Mehta    Male    1952-02-17     Lucknow
# 5            6     Ritu Rodriguez    Male    1989-08-13      Bhopal
# 6            7  Patricia Malhotra  Female    1999-05-17   Bengaluru
# 7            8     Kiran Malhotra    Male    2003-05-02   Hyderabad
# 8            9        Rahul Gupta  Female    1957-08-28     Chennai
# 9           10       Linda Chopra  Female    1977-01-15      Mumbai
#
#             state       phone                   email             occupation  \
# 0         Gujarat  9562078082  customer0@mailbank.com                Retired
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    60000 non-null  int64
#  1   name           60000 non-null  object
#  2   gender         60000 non-null  object
#  3   date_of_birth  60000 non-null  object
#  4   city           60000 non-null  object
#  5   state          60000 non-null  object
#  6   phone          60000 non-null  int64
#  7   email          60000 non-null  object
#  8   occupation     60000 non-null  object
#  9   annual_income  60000 non-null  int64
#  10  join_date      60000 non-null  object
#  11  credit_score   60000 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 5.5+ MB

# %%
customers.isnull().sum()
# Out:
# customer_id      0
# name             0
# gender           0
# date_of_birth    0
# city             0
# state            0
# phone            0
# email            0
# occupation       0
# annual_income    0
# join_date        0
# credit_score     0
# dtype: int64

# %%
customers['date_of_birth'] = pd.to_datetime(customers['date_of_birth'])
customers['join_date'] = pd.to_datetime(customers['join_date'])

# %%
customers['email'].duplicated().sum()
# Out:
# np.int64(0)

# %%
import random

customers['email'] = customers['name'].apply(
    lambda x: f'{x.lower().strip().replace(' ', '',)}{random.randint(100, 100001)}@gmail.com'
)

# %%
customers.head(10)
# Out:
#    customer_id               name  gender date_of_birth        city  \
# 0            1       Pooja Garcia    Male    1987-12-11   Ahmedabad
# 1            2      Anjali Kapoor  Female    1965-12-18     Lucknow
# 2            3        James Smith  Female    1979-03-12  Chandigarh
# 3            4        Susan Joshi    Male    1996-11-07      Nagpur
# 4            5        Kiran Mehta    Male    1952-02-17     Lucknow
# 5            6     Ritu Rodriguez    Male    1989-08-13      Bhopal
# 6            7  Patricia Malhotra  Female    1999-05-17   Bengaluru
# 7            8     Kiran Malhotra    Male    2003-05-02   Hyderabad
# 8            9        Rahul Gupta  Female    1957-08-28     Chennai
# 9           10       Linda Chopra  Female    1977-01-15      Mumbai
#
#             state       phone                            email  \
# 0         Gujarat  9562078082       poojagarcia29145@gmail.com
# 1   Uttar Pradesh  9599825073       anjalikapoor7003@gmail.com
# ...

# %%
customers['email'].value_counts()[customers['email'].value_counts() > 1]
# Out:
# email
# susankumar41307@gmail.com         2
# barbaradavis80699@gmail.com       2
# josephverma49431@gmail.com        2
# anitamehta78374@gmail.com         2
# kavyawilliams34297@gmail.com      2
# kavyajoshi50101@gmail.com         2
# sanjaysharma3989@gmail.com        2
# michaelmartinez42820@gmail.com    2
# sarahkapoor13001@gmail.com        2
# robertverma61498@gmail.com        2
# jenniferjones11337@gmail.com      2
# anjalijoshi28736@gmail.com        2
# williamverma87798@gmail.com       2
# Name: count, dtype: int64

# %%
# Modity only the duplicated values
duplicated_count = customers.groupby('email').cumcount()

customers['email'] = customers['email'].mask(
    duplicated_count > 0,
    customers['email'].str.split('@').str[0]
    + duplicated_count.astype(str)
    + '@'
    + customers['email'].str.split('@').str[1]
)

# %%
customers['email'].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers[customers.duplicated(subset = 'email')]
# Out:
# Empty DataFrame
# Columns: [customer_id, name, gender, date_of_birth, city, state, phone, email, occupation, annual_income, join_date, credit_score]
# Index: []

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.nlargest(1, 'credit_score')
# Out:
#      customer_id           name  gender date_of_birth    city        state  \
# 214          215  Suresh Sharma  Female    2001-09-06  Mumbai  Maharashtra
#
#           phone                        email             occupation  \
# 214  9715881361  sureshsharma64470@gmail.com  Salaried - Government
#
#      annual_income  join_date  credit_score
# 214        2619452 2024-03-13           899

# %%
customers.nsmallest(1, 'credit_score')
# Out:
#      customer_id            name  gender date_of_birth   city   state  \
# 400          401  Susan Martinez  Female    2004-07-30  Kochi  Kerala
#
#           phone                         email  occupation  annual_income  \
# 400  9437587286  susanmartinez80162@gmail.com  Freelancer        1339942
#
#      join_date  credit_score
# 400 2020-10-24           300

# %%
bins = [350, 550, 650, 750, 850, 950]
labels = ['Poor', 'Average', 'Good', 'Very Good', 'Excelent']

customers['credit_status'] = pd.cut(
    customers['credit_score'],
    bins = bins,
    labels = labels
)

# %%
customers
# Out:
#        customer_id             name  gender date_of_birth        city  \
# 0                1     Pooja Garcia    Male    1987-12-11   Ahmedabad
# 1                2    Anjali Kapoor  Female    1965-12-18     Lucknow
# 2                3      James Smith  Female    1979-03-12  Chandigarh
# 3                4      Susan Joshi    Male    1996-11-07      Nagpur
# 4                5      Kiran Mehta    Male    1952-02-17     Lucknow
# ...            ...              ...     ...           ...         ...
# 59995        59996      Priya Desai  Female    1988-08-02   Ahmedabad
# 59996        59997      Susan Verma    Male    1985-10-26     Chennai
# 59997        59998  Meera Rodriguez    Male    1965-05-05      Nagpur
# 59998        59999   Jennifer Desai    Male    2003-11-08      Jaipur
# 59999        60000     Joseph Joshi    Male    1978-07-21      Jaipur
#
#                state       phone                          email  \
# ...

# %%
customers['phone'] = (
    '+91 ' + customers['phone'].astype(str)
)

# %%
customers.head()
# Out:
#    customer_id           name  gender date_of_birth        city  \
# 0            1   Pooja Garcia    Male    1987-12-11   Ahmedabad
# 1            2  Anjali Kapoor  Female    1965-12-18     Lucknow
# 2            3    James Smith  Female    1979-03-12  Chandigarh
# 3            4    Susan Joshi    Male    1996-11-07      Nagpur
# 4            5    Kiran Mehta    Male    1952-02-17     Lucknow
#
#            state           phone                       email  \
# 0        Gujarat  +91 9562078082  poojagarcia29145@gmail.com
# 1  Uttar Pradesh  +91 9599825073  anjalikapoor7003@gmail.com
# 2         Punjab  +91 9572599111   jamessmith97836@gmail.com
# 3    Maharashtra  +91 9364883923   susanjoshi70391@gmail.com
# 4  Uttar Pradesh  +91 9753361420    kiranmehta8130@gmail.com
#
#               occupation  annual_income  join_date  credit_score credit_status
# 0                Retired         200025 2018-02-23           690          Good
# ...

# %%
customers['join_month'] = customers['join_date'].dt.month_name()
customers['join_year'] = customers['join_date'].dt.year

# %%
customers
# Out:
#        customer_id             name  gender date_of_birth        city  \
# 0                1     Pooja Garcia    Male    1987-12-11   Ahmedabad
# 1                2    Anjali Kapoor  Female    1965-12-18     Lucknow
# 2                3      James Smith  Female    1979-03-12  Chandigarh
# 3                4      Susan Joshi    Male    1996-11-07      Nagpur
# 4                5      Kiran Mehta    Male    1952-02-17     Lucknow
# ...            ...              ...     ...           ...         ...
# 59995        59996      Priya Desai  Female    1988-08-02   Ahmedabad
# 59996        59997      Susan Verma    Male    1985-10-26     Chennai
# 59997        59998  Meera Rodriguez    Male    1965-05-05      Nagpur
# 59998        59999   Jennifer Desai    Male    2003-11-08      Jaipur
# 59999        60000     Joseph Joshi    Male    1978-07-21      Jaipur
#
#                state           phone                          email  \
# ...

# %%
emp
# Out:
#       employee_id               name  branch_id                  role  \
# 0               1  Richard Rodriguez         30      Customer Service
# 1               2   Robert Rodriguez        136  Relationship Manager
# 2               3    Arjun Rodriguez         35      Customer Service
# 3               4        Arjun Singh        146          Loan Officer
# 4               5       Robert Joshi         29      Customer Service
# ...           ...                ...        ...                   ...
# 1795         1796     Jennifer Smith         65          Loan Officer
# 1796         1797       Suresh Desai         47  Relationship Manager
# 1797         1798     Barbara Chopra        123  Relationship Manager
# 1798         1799       Sanjay Kumar         62                Teller
# 1799         1800     Jennifer Menon         49                Teller
#
#        hire_date  salary
# 0     2016-11-09   62479
# 1     2010-08-04   50855
# 2     2020-02-12   94948
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  1800 non-null   int64
#  1   name         1800 non-null   object
#  2   branch_id    1800 non-null   int64
#  3   role         1800 non-null   object
#  4   hire_date    1800 non-null   object
#  5   salary       1800 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 84.5+ KB

# %%
emp['hire_date'] = pd.to_datetime(emp['hire_date'])

# %%
emp.isnull().sum()
# Out:
# employee_id    0
# name           0
# branch_id      0
# role           0
# hire_date      0
# salary         0
# dtype: int64

# %%
emp['employee_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
emp['join_month'] = emp['hire_date'].dt.month_name()
emp['year'] = emp['hire_date'].dt.year

# %%
emp['salary'] = pd.to_numeric(emp['salary']).astype(float)

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  1800 non-null   int64
#  1   name         1800 non-null   object
#  2   branch_id    1800 non-null   int64
#  3   role         1800 non-null   object
#  4   hire_date    1800 non-null   datetime64[ns]
#  5   salary       1800 non-null   float64
#  6   join_month   1800 non-null   object
#  7   year         1800 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(2), object(3)
# memory usage: 105.6+ KB

# %%
emp.head()
# Out:
#    employee_id               name  branch_id                  role  hire_date  \
# 0            1  Richard Rodriguez         30      Customer Service 2016-11-09
# 1            2   Robert Rodriguez        136  Relationship Manager 2010-08-04
# 2            3    Arjun Rodriguez         35      Customer Service 2020-02-12
# 3            4        Arjun Singh        146          Loan Officer 2022-02-11
# 4            5       Robert Joshi         29      Customer Service 2010-05-09
#
#      salary join_month  year
# 0   62479.0   November  2016
# 1   50855.0     August  2010
# 2   94948.0   February  2020
# 3   40756.0   February  2022
# 4  155016.0        May  2010

# %%
loan_payments.head()
# Out:
#    payment_id  loan_id payment_date  amount_paid  principal_component  \
# 0           1    21070   2020-05-06      8144.05              5930.89
# 1           2    17959   2011-09-23      6128.01              4406.78
# 2           3     7239   2025-02-25     27946.17             25195.76
# 3           4     9993   2015-10-04      5715.37              4082.41
# 4           5     5487   2017-07-26     10119.72              9474.29
#
#    interest_component  late_payment_flag
# 0             2213.16                  0
# 1             1721.23                  0
# 2             2750.41                  0
# 3             1632.96                  0
# 4              645.43                  0

# %%
loan_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600000 entries, 0 to 599999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   payment_id           600000 non-null  int64
#  1   loan_id              600000 non-null  int64
#  2   payment_date         600000 non-null  object
#  3   amount_paid          600000 non-null  float64
#  4   principal_component  600000 non-null  float64
#  5   interest_component   600000 non-null  float64
#  6   late_payment_flag    600000 non-null  int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 32.0+ MB

# %%
loan_payments.describe()
# Out:
#           payment_id        loan_id    amount_paid  principal_component  \
# count  600000.000000  600000.000000  600000.000000        600000.000000
# mean   300000.500000   11003.130957   10397.459895          8487.303101
# std    173205.225094    6343.123591    9856.840472          7988.881191
# min         1.000000       1.000000     526.270000           500.030000
# 25%    150000.750000    5516.000000    3409.955000          2798.770000
# 50%    300000.500000   10997.000000    7361.825000          6032.060000
# 75%    450000.250000   16495.000000   14138.020000         11571.875000
# max    600000.000000   22000.000000  147281.590000        110436.890000
#
#        interest_component  late_payment_flag
# count       600000.000000      600000.000000
# mean          1910.156795           0.120063
# std           2148.616537           0.325036
# min             25.400000           0.000000
# 25%            505.977500           0.000000
# 50%           1177.950000           0.000000
# ...

# %%
loan_payments.isnull().sum()
# Out:
# payment_id             0
# loan_id                0
# payment_date           0
# amount_paid            0
# principal_component    0
# interest_component     0
# late_payment_flag      0
# dtype: int64

# %%
loan_payments.duplicated(subset='payment_id').sum()
# Out:
# np.int64(0)

# %%
loan_payments['late_payment_flag'].unique()
# Out:
# array([0, 1])

# %%
loan_payments.columns
# Out:
# Index(['payment_id', 'loan_id', 'payment_date', 'amount_paid',
#        'principal_component', 'interest_component', 'late_payment_flag'],
#       dtype='object')

# %%
loan_payments['payment_date'] = pd.to_datetime(loan_payments['payment_date'])

# %%
loan_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600000 entries, 0 to 599999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   payment_id           600000 non-null  int64
#  1   loan_id              600000 non-null  int64
#  2   payment_date         600000 non-null  datetime64[ns]
#  3   amount_paid          600000 non-null  float64
#  4   principal_component  600000 non-null  float64
#  5   interest_component   600000 non-null  float64
#  6   late_payment_flag    600000 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(3)
# memory usage: 32.0 MB

# %%
loans.head()
# Out:
#    loan_id  customer_id  branch_id       loan_type  loan_amount  \
# 0        1        48019        129       Auto Loan    310670.27
# 1        2        47355         38  Education Loan    599321.65
# 2        3        30661         29       Gold Loan    135377.18
# 3        4         1755         66  Education Loan     20798.63
# 4        5        18763         23  Education Loan     84367.97
#
#    interest_rate  term_months  start_date     status
# 0           9.54           60  2020-06-16     Active
# 1          16.20           12  2016-06-05     Active
# 2          10.25           24  2012-07-03     Active
# 3           8.37          180  2013-01-27  Defaulted
# 4           8.97           60  2017-02-11     Active

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   loan_id        22000 non-null  int64
#  1   customer_id    22000 non-null  int64
#  2   branch_id      22000 non-null  int64
#  3   loan_type      22000 non-null  object
#  4   loan_amount    22000 non-null  float64
#  5   interest_rate  22000 non-null  float64
#  6   term_months    22000 non-null  int64
#  7   start_date     22000 non-null  object
#  8   status         22000 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.5+ MB

# %%
loans.isnull().sum()
# Out:
# loan_id          0
# customer_id      0
# branch_id        0
# loan_type        0
# loan_amount      0
# interest_rate    0
# term_months      0
# start_date       0
# status           0
# dtype: int64

# %%
loans['loan_type'].unique()
# Out:
# array(['Auto Loan', 'Education Loan', 'Gold Loan', 'Home Loan',
#        'Personal Loan', 'Business Loan'], dtype=object)

# %%
support.head()
# Out:
#    ticket_id  customer_id       issue_type date_opened date_resolved  \
# 0          1        16045  App Login Issue  2024-08-04    2024-08-19
# 1          2         8088  App Login Issue  2021-07-13    2021-07-27
# 2          3        47568     Card Blocked  2021-06-23    2021-07-08
# 3          4        36826       KYC Update  2022-12-04    2022-12-18
# 4          5         7289   Interest Query  2023-06-22    2023-07-11
#
#      status  satisfaction_score
# 0  Resolved                   5
# 1  Resolved                   1
# 2  Resolved                   3
# 3  Resolved                   4
# 4      Open                   5

# %%
support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ticket_id           25000 non-null  int64
#  1   customer_id         25000 non-null  int64
#  2   issue_type          25000 non-null  object
#  3   date_opened         25000 non-null  object
#  4   date_resolved       25000 non-null  object
#  5   status              25000 non-null  object
#  6   satisfaction_score  25000 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 1.3+ MB

# %%
support['date_opened'] = pd.to_datetime(support['date_opened'])
support['date_resolved'] = pd.to_datetime(support['date_resolved'])

# %%
support.isnull().sum()
# Out:
# ticket_id             0
# customer_id           0
# issue_type            0
# date_opened           0
# date_resolved         0
# status                0
# satisfaction_score    0
# dtype: int64

# %%
support['ticket_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ticket_id           25000 non-null  int64
#  1   customer_id         25000 non-null  int64
#  2   issue_type          25000 non-null  object
#  3   date_opened         25000 non-null  datetime64[ns]
#  4   date_resolved       25000 non-null  datetime64[ns]
#  5   status              25000 non-null  object
#  6   satisfaction_score  25000 non-null  int64
# dtypes: datetime64[ns](2), int64(3), object(2)
# memory usage: 1.3+ MB

# %%
transactions.head()
# Out:
#    transaction_id  account_id    txn_date         txn_type    amount  \
# 0               1       42369  2018-03-13          Deposit   1817.91
# 1               2       53934  2022-03-05       Withdrawal  12855.96
# 2               3       53478  2022-05-29          Deposit   8278.61
# 3               4        5270  2024-01-27  Interest Credit  18183.95
# 4               5       85021  2023-01-19        Fee Debit  19658.07
#
#           channel merchant_category
# 0  Online Banking     Salary Credit
# 1      Mobile App    ATM Withdrawal
# 2             UPI         Education
# 3          Branch            Dining
# 4             UPI    ATM Withdrawal

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   transaction_id     int64
#  1   account_id         int64
#  2   txn_date           object
#  3   txn_type           object
#  4   amount             float64
#  5   channel            object
#  6   merchant_category  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 106.8+ MB

# %%
transactions['txn_date'] = pd.to_datetime(transactions['txn_date'])

# %%
transactions['txn_type'].unique()
# Out:
# array(['Deposit', 'Withdrawal', 'Interest Credit', 'Fee Debit',
#        'Transfer Out', 'Transfer In'], dtype=object)

# %%
transactions['channel'].unique()
# Out:
# array(['Online Banking', 'Mobile App', 'UPI', 'Branch', 'POS', 'ATM'],
#       dtype=object)

# %%
transactions['merchant_category'].unique()
# Out:
# array(['Salary Credit', 'ATM Withdrawal', 'Education', 'Dining',
#        'Shopping', 'Utilities', 'Entertainment', 'Fuel', 'Insurance',
#        'Healthcare', 'Groceries', 'Travel', 'Fund Transfer', 'Rent'],
#       dtype=object)

# %%
accounts.shape
# Out:
# (95000, 6)

# %%
accounts.columns
# Out:
# Index(['customer_id', 'branch_id', 'account_type', 'balance', 'open_date',
#        'status'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Gender Distribution

gender_distribution = (customers['gender'].value_counts(normalize=True) * 100).round(2)

gender_distribution
# Out:
# gender
# Male      52.24
# Female    45.69
# Other      2.07
# Name: proportion, dtype: float64

# %%
# customers age
from datetime import datetime

today = datetime.today()

customers['age'] = (
    today.year
    - customers['date_of_birth'].dt.year
    - (
        (today.month < customers['date_of_birth'].dt.month)
        | (
            (today.month == customers['date_of_birth'].dt.month)
            & (today.day < customers['date_of_birth'].dt.day)
        )
    )
)

# %%
# Creating age groups
bins = [18, 25, 35, 45, 55, 65, 100]
labels = ['Young Adult', 'Adult', 'Senior Adult', 'Middle Aged', 'Senior', 'Old Aged']

customers['age_group'] = pd.cut(
    customers['age'],
    bins = bins,
    labels = labels
)

# %%
customers[['date_of_birth', 'age', 'age_group']].head()
# Out:
#   date_of_birth  age     age_group
# 0    1987-12-11   38  Senior Adult
# 1    1965-12-18   60        Senior
# 2    1979-03-12   47   Middle Aged
# 3    1996-11-07   29         Adult
# 4    1952-02-17   74      Old Aged

# %%
customers.head()
# Out:
#    customer_id           name  gender date_of_birth        city  \
# 0            1   Pooja Garcia    Male    1987-12-11   Ahmedabad
# 1            2  Anjali Kapoor  Female    1965-12-18     Lucknow
# 2            3    James Smith  Female    1979-03-12  Chandigarh
# 3            4    Susan Joshi    Male    1996-11-07      Nagpur
# 4            5    Kiran Mehta    Male    1952-02-17     Lucknow
#
#            state           phone                       email  \
# 0        Gujarat  +91 9562078082  poojagarcia29145@gmail.com
# 1  Uttar Pradesh  +91 9599825073  anjalikapoor7003@gmail.com
# 2         Punjab  +91 9572599111   jamessmith97836@gmail.com
# 3    Maharashtra  +91 9364883923   susanjoshi70391@gmail.com
# 4  Uttar Pradesh  +91 9753361420    kiranmehta8130@gmail.com
#
#               occupation  annual_income  join_date  credit_score  \
# 0                Retired         200025 2018-02-23           690
# 1  Salaried - Government        1865003 2020-11-08           672
# ...

# %% [markdown]
# #### Customer Anlysis

# %%
# Counts the number of customers by city
customers_by_city = customers['city'].value_counts()

# %%
customers_by_city
# Out:
# city
# Chandigarh    4123
# Bengaluru     4093
# Lucknow       4047
# Indore        4044
# Mumbai        4032
# Ahmedabad     4028
# Bhopal        4015
# Kolkata       4011
# Pune          3990
# Chennai       3974
# Nagpur        3959
# Hyderabad     3958
# Delhi         3938
# Kochi         3910
# Jaipur        3878
# Name: count, dtype: int64

# %%
# Counts the number of customers by state

customers_by_state = customers['state'].value_counts()

customers_by_state
# Out:
# state
# Maharashtra       11981
# Madhya Pradesh     8059
# Punjab             4123
# Karnataka          4093
# Uttar Pradesh      4047
# Gujarat            4028
# West Bengal        4011
# Tamil Nadu         3974
# Telangana          3958
# Delhi              3938
# Kerala             3910
# Rajasthan          3878
# Name: count, dtype: int64

# %%
state_percentage = (customers['state'].value_counts(normalize=True)* 100).round(2)

state_percentage
# Out:
# state
# Maharashtra       19.97
# Madhya Pradesh    13.43
# Punjab             6.87
# Karnataka          6.82
# Uttar Pradesh      6.74
# Gujarat            6.71
# West Bengal        6.68
# Tamil Nadu         6.62
# Telangana          6.60
# Delhi              6.56
# Kerala             6.52
# Rajasthan          6.46
# Name: proportion, dtype: float64

# %%
location_summary = pd.DataFrame({
    'no_customers' : customers['state'].value_counts(),
    'percentage' : (customers['state'].value_counts(normalize=True)* 100).round(2)
})

location_summary
# Out:
#                 no_customers  percentage
# state
# Maharashtra            11981       19.97
# Madhya Pradesh          8059       13.43
# Punjab                  4123        6.87
# Karnataka               4093        6.82
# Uttar Pradesh           4047        6.74
# Gujarat                 4028        6.71
# West Bengal             4011        6.68
# Tamil Nadu              3974        6.62
# Telangana               3958        6.60
# Delhi                   3938        6.56
# Kerala                  3910        6.52
# Rajasthan               3878        6.46

# %%
cities_percentage = (customers['city'].value_counts(normalize=True)* 100).round(2)

cities_percentage
# Out:
# city
# Chandigarh    6.87
# Bengaluru     6.82
# Lucknow       6.74
# Indore        6.74
# Mumbai        6.72
# Ahmedabad     6.71
# Bhopal        6.69
# Kolkata       6.68
# Pune          6.65
# Chennai       6.62
# Nagpur        6.60
# Hyderabad     6.60
# Delhi         6.56
# Kochi         6.52
# Jaipur        6.46
# Name: proportion, dtype: float64

# %%
# Top 10 cities with the most customers
top_10_cities_with_customers = (customers['city'].value_counts()).head(10)

top_10_cities_with_customers
# Out:
# city
# Chandigarh    4123
# Bengaluru     4093
# Lucknow       4047
# Indore        4044
# Mumbai        4032
# Ahmedabad     4028
# Bhopal        4015
# Kolkata       4011
# Pune          3990
# Chennai       3974
# Name: count, dtype: int64

# %% [markdown]
# #### Customer occupation distribution

# %%
# count customers by occupation
customers_by_occupation = customers['occupation'].value_counts()

customers_by_occupation
# Out:
# occupation
# Freelancer               8651
# Salaried - Private       8643
# Business Owner           8643
# Salaried - Government    8634
# Retired                  8509
# Self Employed            8492
# Student                  8428
# Name: count, dtype: int64

# %%
# Customers occupation percentage
occupation_percentage = (customers['occupation'].value_counts(normalize=True)* 100).round(2)

occupation_percentage
# Out:
# occupation
# Freelancer               14.42
# Salaried - Private       14.40
# Business Owner           14.40
# Salaried - Government    14.39
# Retired                  14.18
# Self Employed            14.15
# Student                  14.05
# Name: proportion, dtype: float64

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize = (15,5))
fig.set_facecolor('white')
ax.set_facecolor('white')

top_5_states = customers['state'].value_counts().head(5)

top_5_states.plot(kind = 'bar', ax = ax, color = 'blue', width = 0.4, edgecolor = 'black')

for container in ax.containers:
    ax.bar_label(container, fmt = '{:,.0f}', padding = 0, fontweight = 'bold')

plt.title("Top 5 States by Number of Customers", fontweight = 'bold', fontsize = 35, color = 'purple')
plt.xlabel('State', fontweight = 'bold', fontsize = 15, color = 'purple')
plt.ylabel('Number of Customers', fontweight = 'bold', fontsize = 15, color = 'purple')
plt.xticks(fontsize = 10, fontstyle = 'italic', rotation = 0, fontweight = 'bold')
plt.show()

# %%
import matplotlib
print(matplotlib.get_backend())
# Out:
# inline

# %% [markdown]
# #### Accounts Analysis

# %%
accounts.head()
# Out:
#             customer_id  branch_id account_type   balance  open_date  status
# account_id
# 1                 11749        141      Current  95902.00 2019-10-20  Active
# 2                 47716         43      Current  13261.61 2026-02-03  Active
# 3                 56143         90      Savings  26495.92 2020-10-19  Active
# 4                 29193        113       Salary  74682.72 2012-02-22  Active
# 5                 49907         28      Current  40419.01 2007-01-03  Active

# %%
# Accounts Distribution
total_accounts = [accounts.shape[0]]

total_accounts
# Out:
# [95000]

# %%
accounts['status'].unique()
# Out:
# array(['Active', 'Dormant', 'Closed'], dtype=object)

# %%
# Accounts status summary
accunts_summary = pd.DataFrame({
    "total_accounts" : [accounts.shape[0]],
    "active_accounts" : [(accounts['status'] == 'Active').sum()],
    "dormant_accounts" : [(accounts['status'] == 'Dormant').sum()],
    "closed_accounts" : [(accounts['status'] == 'Closed').sum()]
})

print(accunts_summary)
# Out:
#    total_accounts  active_accounts  dormant_accounts  closed_accounts
# 0           95000            80707              9526             4767

# %%
active_accounts = (accounts['status'] == 'Active').sum()
dormant_accounts = (accounts['status'] == 'Dormant').sum()
closed_accounts = (accounts['status'] == 'Closed').sum()

print(active_accounts)
print(dormant_accounts)
print(closed_accounts)
# Out:
# 80707
# 9526
# 4767

# %%
total_accounts = accounts.shape[0]

total_accounts
# Out:
# 95000

# %%
accout_status = accounts['status'].value_counts()
accout_status
# Out:
# status
# Active     80707
# Dormant     9526
# Closed      4767
# Name: count, dtype: int64

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize = (10,5))

ax.plot(accout_status.index, accout_status.values, marker= 'o', linewidth = 2, color = 'green')

for x, y in zip(accout_status.index, accout_status.values):
    ax.text(x, y, f'{y:,}', ha = 'center', va = 'top')
plt.title("Account Status Summary", color = 'white', fontweight = 'bold', fontsize= 20,
         bbox = dict(facecolor = 'purple', edgecolor = 'white', boxstyle = 'round'))
plt.xlabel("Status", color = 'black', fontweight = 'bold', fontsize = 10)
plt.ylabel('No_of Accounts', color = 'black', fontweight = 'bold', fontsize= 10)
plt.xticks(fontweight = 'bold', color = 'purple', fontsize= 8)
plt.yticks(fontweight = 'bold', color = 'purple', fontsize = 8)
plt.grid(True)
plt.show()

# %%
accounts['account_type'].unique()
# Out:
# array(['Current', 'Savings', 'Salary', 'Fixed Deposit', 'NRI'],
#       dtype=object)

# %%
# accout type distribution
account_types = accounts['account_type'].value_counts()

account_types
# Out:
# account_type
# Savings          47557
# Current          19021
# Salary           14270
# Fixed Deposit     9458
# NRI               4694
# Name: count, dtype: int64

# %%
type_summary = pd.DataFrame({
    "no_customers" : accounts['account_type'].value_counts(),
    "percentage" : (accounts['account_type'].value_counts(normalize=True)*100).round(2)
})

type_summary
# Out:
#                no_customers  percentage
# account_type
# Savings               47557       50.06
# Current               19021       20.02
# Salary                14270       15.02
# Fixed Deposit          9458        9.96
# NRI                    4694        4.94

# %%
type_summary.reset_index(inplace=True)

# %%
type_summary
# Out:
#     account_type  no_customers  percentage
# 0        Savings         47557       50.06
# 1        Current         19021       20.02
# 2         Salary         14270       15.02
# 3  Fixed Deposit          9458        9.96
# 4            NRI          4694        4.94

# %%
# Average balance per account type
average_balance_per_type = (accounts.groupby('account_type')['balance'].mean()).round(2)

average_balance_per_type
# Out:
# account_type
# Current          45744.84
# Fixed Deposit    45019.02
# NRI              46657.61
# Salary           45193.94
# Savings          45997.15
# Name: balance, dtype: float64

# %%
accounts
# Out:
#             customer_id  branch_id   account_type    balance  open_date  \
# account_id
# 1                 11749        141        Current   95902.00 2019-10-20
# 2                 47716         43        Current   13261.61 2026-02-03
# 3                 56143         90        Savings   26495.92 2020-10-19
# 4                 29193        113         Salary   74682.72 2012-02-22
# 5                 49907         28        Current   40419.01 2007-01-03
# ...                 ...        ...            ...        ...        ...
# 94996             43366         38  Fixed Deposit   66228.51 2012-03-18
# 94997             50856         12        Current   39854.55 2011-10-21
# 94998              8593         68        Current    9310.24 2021-03-22
# 94999             49233        107  Fixed Deposit   13110.16 2009-10-16
# 95000             53515         34        Savings  221443.76 2025-08-11
#
#             status
# account_id
# 1           Active
# 2           Active
# ...

# %%
accounts['year_month'] = accounts['open_date'].dt.to_period('M').astype(str)

# %%
accounts.columns
# Out:
# Index(['customer_id', 'branch_id', 'account_type', 'balance', 'open_date',
#        'status', 'year_month'],
#       dtype='object')

# %%
accounts['year_month'].head()
# Out:
# account_id
# 1    2019-10
# 2    2026-02
# 3    2020-10
# 4    2012-02
# 5    2007-01
# Name: year_month, dtype: object

# %%
# How many accounts are opened in each month
monthly_accounts = accounts['year_month'].value_counts().sort_index()

monthly_accounts
# Out:
# year_month
# 2005-01    355
# 2005-02    331
# 2005-03    385
# 2005-04    380
# 2005-05    392
#           ...
# 2026-01    371
# 2026-02    316
# 2026-03    393
# 2026-04    367
# 2026-05    361
# Name: count, Length: 257, dtype: int64

# %%
accounts['year'] = accounts['open_date'].dt.to_period('Y').astype(str)

# %%
# How many accounts are opened in each year
yearly_accounts = accounts['year'].value_counts().sort_index()

yearly_accounts
# Out:
# year
# 2005    4426
# 2006    4488
# 2007    4412
# 2008    4478
# 2009    4409
# 2010    4394
# 2011    4326
# 2012    4438
# 2013    4469
# 2014    4489
# 2015    4530
# 2016    4405
# 2017    4457
# 2018    4409
# 2019    4376
# 2020    4416
# 2021    4471
# 2022    4362
# 2023    4497
# 2024    4584
# 2025    4356
# 2026    1808
# Name: count, dtype: int64

# %%
# Most common account type and its count
most_common = accounts['account_type'].value_counts()

print('Most Common account Type is:', most_common.index[0])
print('Number of Accounts:', most_common.iloc[0])
# Out:
# Most Common account Type is: Savings
# Number of Accounts: 47557

# %%
# Find 0 balance accounts
# (accounts['balance'] == 0).sum()
zero_balance = accounts[accounts['balance'] == 0]

print("Number of Zero Balance Accounts:", zero_balance.shape[0])
# Out:
# Number of Zero Balance Accounts: 0

# %% [markdown]
# #### Transaction Analysis

# %%
transactions.head()
# Out:
#    transaction_id  account_id   txn_date         txn_type    amount  \
# 0               1       42369 2018-03-13          Deposit   1817.91
# 1               2       53934 2022-03-05       Withdrawal  12855.96
# 2               3       53478 2022-05-29          Deposit   8278.61
# 3               4        5270 2024-01-27  Interest Credit  18183.95
# 4               5       85021 2023-01-19        Fee Debit  19658.07
#
#           channel merchant_category
# 0  Online Banking     Salary Credit
# 1      Mobile App    ATM Withdrawal
# 2             UPI         Education
# 3          Branch            Dining
# 4             UPI    ATM Withdrawal

# %%
transactions['txn_type'].unique()
# Out:
# array(['Deposit', 'Withdrawal', 'Interest Credit', 'Fee Debit',
#        'Transfer Out', 'Transfer In'], dtype=object)

# %%
transactions['trans_month'] = transactions['txn_date'].dt.month_name()

# %%
transactions['trans_year'] = transactions['txn_date'].dt.year

# %%
transactions[['trans_month', 'trans_year']].head()
# Out:
#   trans_month  trans_year
# 0       March        2018
# 1       March        2022
# 2         May        2022
# 3     January        2024
# 4     January        2023

# %%
transactions.columns
# Out:
# Index(['transaction_id', 'account_id', 'txn_date', 'txn_type', 'amount',
#        'channel', 'merchant_category', 'trans_month', 'trans_year'],
#       dtype='object')

# %%
# Transaction type distribution
transaction_type_distribution = transactions['txn_type'].value_counts()

transaction_type_distribution
# Out:
# txn_type
# Withdrawal         499405
# Deposit            498861
# Transfer Out       301321
# Transfer In        300258
# Fee Debit          200209
# Interest Credit    199946
# Name: count, dtype: int64

# %%
# Transaction type by amount
trans_amount = (transactions.groupby('txn_type')['amount'].sum().sort_values(ascending=True).reset_index())

trans_amount
# Out:
#           txn_type        amount
# 0  Interest Credit  1.206454e+09
# 1        Fee Debit  1.208979e+09
# 2      Transfer In  1.816111e+09
# 3     Transfer Out  1.828299e+09
# 4       Withdrawal  3.017945e+09
# 5          Deposit  3.018981e+09

# %%
trans_amount['amount'] = trans_amount['amount'].map('{:,.2f}'.format)
trans_amount
# Out:
#           txn_type            amount
# 0  Interest Credit  1,206,454,378.77
# 1        Fee Debit  1,208,979,396.89
# 2      Transfer In  1,816,111,445.06
# 3     Transfer Out  1,828,298,505.01
# 4       Withdrawal  3,017,944,605.74
# 5          Deposit  3,018,980,902.58

# %%
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize = (10,4))
transactions.boxplot(column='amount', by = 'txn_type', ax=ax)
plt.title("Transaction Amount by Transaction Type")
plt.xlabel("Transaction Type")
plt.suptitle('')
plt.ylabel("Amount")
plt.grid(False)
plt.show()

# %% [markdown]
# ###### Calculate Daily Transactions

# %%
daily_transactions = transactions.groupby('txn_date').size()

daily_transactions
# Out:
# txn_date
# 2018-01-01    667
# 2018-01-02    577
# 2018-01-03    615
# 2018-01-04    638
# 2018-01-05    622
#              ...
# 2026-06-26    672
# 2026-06-27    695
# 2026-06-28    653
# 2026-06-29    627
# 2026-06-30    638
# Length: 3103, dtype: int64

# %%
daily_transactions = transactions.groupby('txn_date')['amount'].sum()

daily_transactions
# Out:
# txn_date
# 2018-01-01    3856297.62
# 2018-01-02    3520662.87
# 2018-01-03    3574253.32
# 2018-01-04    3637042.44
# 2018-01-05    3800268.39
#                  ...
# 2026-06-26    4046071.23
# 2026-06-27    4028661.61
# 2026-06-28    3904115.67
# 2026-06-29    3873623.36
# 2026-06-30    3648462.35
# Name: amount, Length: 3103, dtype: float64

# %%
transactions.columns
# Out:
# Index(['transaction_id', 'account_id', 'txn_date', 'txn_type', 'amount',
#        'channel', 'merchant_category', 'trans_month', 'trans_year'],
#       dtype='object')

# %%
transactions.shape
# Out:
# (2000000, 9)

# %%
# Transactions amount calaculation 
trans_amount_calculation = transactions.groupby('trans_month').agg(
    
    average_amount = ('amount', 'mean'),
    maximum_amount = ('amount', 'max'),
    minimum_amount = ('amount', 'min'),
    total_amount = ('amount', 'sum'),
    total_transactions = ('amount', 'count')
)

trans_amount_calculation
# Out:
#              average_amount  maximum_amount  minimum_amount  total_amount  \
# trans_month
# April           6048.822616        73476.11           50.01  1.053542e+09
# August          6028.191421        84220.47           50.01  9.616472e+08
# December        6024.416320        77167.15           50.02  9.621897e+08
# February        6077.265262        74687.59           50.05  9.953224e+08
# January         6024.310425        70806.97           50.04  1.082057e+09
# July            6060.250106        77046.48           50.04  9.698764e+08
# June            6045.756325        64374.51           50.01  1.058884e+09
# March           6062.855546        97785.89           50.01  1.085548e+09
# May             6069.999229        92364.93           50.07  1.093146e+09
# November        6045.791735        66130.30           50.03  9.353989e+08
# October         6054.570950        77594.51           50.03  9.680290e+08
# ...

# %%
trans_amount_calculation['total_amount'] = trans_amount_calculation['total_amount'].map('{:,.2f}'.format)
trans_amount_calculation
# Out:
#              average_amount  maximum_amount  minimum_amount      total_amount  \
# trans_month
# April           6048.822616        73476.11           50.01  1,053,541,581.57
# August          6028.191421        84220.47           50.01    961,647,236.46
# December        6024.416320        77167.15           50.02    962,189,652.50
# February        6077.265262        74687.59           50.05    995,322,350.16
# January         6024.310425        70806.97           50.04  1,082,056,517.00
# July            6060.250106        77046.48           50.04    969,876,366.79
# June            6045.756325        64374.51           50.01  1,058,883,991.60
# March           6062.855546        97785.89           50.01  1,085,548,222.69
# May             6069.999229        92364.93           50.07  1,093,146,161.20
# November        6045.791735        66130.30           50.03    935,398,851.48
# October         6054.570950        77594.51           50.03    968,029,021.69
# ...

# %%
trans_amount_calculation
# Out:
#              average_amount  maximum_amount  minimum_amount      total_amount  \
# trans_month
# April           6048.822616        73476.11           50.01  1,053,541,581.57
# August          6028.191421        84220.47           50.01    961,647,236.46
# December        6024.416320        77167.15           50.02    962,189,652.50
# February        6077.265262        74687.59           50.05    995,322,350.16
# January         6024.310425        70806.97           50.04  1,082,056,517.00
# July            6060.250106        77046.48           50.04    969,876,366.79
# June            6045.756325        64374.51           50.01  1,058,883,991.60
# March           6062.855546        97785.89           50.01  1,085,548,222.69
# May             6069.999229        92364.93           50.07  1,093,146,161.20
# November        6045.791735        66130.30           50.03    935,398,851.48
# October         6054.570950        77594.51           50.03    968,029,021.69
# ...

# %%
# Weekly Transactions
weekly_transactions = (transactions
    .groupby(pd.Grouper(key = 'txn_date', freq = 'W'))['amount'].size()
)
display(weekly_transactions.map("{:,.2f}".format))
# Out:
# txn_date
# 2018-01-07    4,409.00
# 2018-01-14    4,486.00
# 2018-01-21    4,501.00
# 2018-01-28    4,550.00
# 2018-02-04    4,569.00
#                 ...
# 2026-06-07    4,592.00
# 2026-06-14    4,550.00
# 2026-06-21    4,631.00
# 2026-06-28    4,663.00
# 2026-07-05    1,265.00
# Freq: W-SUN, Name: amount, Length: 444, dtype: object

# %%
# Total amount per week
weekly_total_amount = (transactions.groupby(pd.Grouper(key='txn_date', freq='W'))['amount']).sum()

display(weekly_total_amount.map("{:,.2f}".format))
# Out:
# txn_date
# 2018-01-07    26,297,392.22
# 2018-01-14    26,344,894.60
# 2018-01-21    27,375,356.85
# 2018-01-28    27,355,499.12
# 2018-02-04    27,956,170.11
#                   ...
# 2026-06-07    27,764,194.31
# 2026-06-14    27,915,404.66
# 2026-06-21    28,985,457.83
# 2026-06-28    28,235,631.09
# 2026-07-05     7,522,085.71
# Freq: W-SUN, Name: amount, Length: 444, dtype: object

# %%
# Monthly Transactions
montly_transactions = (
    transactions.groupby(pd.Grouper(key = 'txn_date', freq = 'ME'))
    .size()
)

montly_transactions
# Out:
# txn_date
# 2018-01-31    20003
# 2018-02-28    18032
# 2018-03-31    19921
# 2018-04-30    19196
# 2018-05-31    20162
#               ...
# 2026-02-28    18011
# 2026-03-31    20035
# 2026-04-30    19380
# 2026-05-31    20150
# 2026-06-30    19701
# Freq: ME, Length: 102, dtype: int64

# %%
# Total amount per month
monthly_total_amount = (transactions.groupby(pd.Grouper(key='txn_date', freq='ME'))['amount']).sum()

display(monthly_total_amount.map("{:,.3f}".format))
# Out:
# txn_date
# 2018-01-31    119,705,872.160
# 2018-02-28    109,727,492.760
# 2018-03-31    121,027,570.880
# 2018-04-30    115,501,276.310
# 2018-05-31    122,568,308.700
#                    ...
# 2026-02-28    109,493,673.430
# 2026-03-31    122,780,277.920
# 2026-04-30    116,940,083.530
# 2026-05-31    122,890,090.510
# 2026-06-30    120,422,773.600
# Freq: ME, Name: amount, Length: 102, dtype: object

# %%
# yearly transactions
yearly_transactions = (
    transactions.groupby(pd.Grouper(key = 'txn_date', freq = 'YE'))
    .size()
)

yearly_transactions
# Out:
# txn_date
# 2018-12-31    235255
# 2019-12-31    235399
# 2020-12-31    235170
# 2021-12-31    236242
# 2022-12-31    235423
# 2023-12-31    234962
# 2024-12-31    235893
# 2025-12-31    234603
# 2026-12-31    117053
# Freq: YE-DEC, dtype: int64

# %%
# yearly total amount
yearly_total_amount = transactions.groupby(pd.Grouper(key='txn_date', freq="YE"))['amount'].sum()

display(yearly_total_amount.map("{:,.2f}".format))
# Out:
# txn_date
# 2018-12-31    1,420,846,295.03
# 2019-12-31    1,423,142,590.61
# 2020-12-31    1,423,627,370.93
# 2021-12-31    1,423,926,982.70
# 2022-12-31    1,428,778,200.73
# 2023-12-31    1,420,147,907.39
# 2024-12-31    1,424,105,082.51
# 2025-12-31    1,420,497,357.75
# 2026-12-31      711,697,446.40
# Freq: YE-DEC, Name: amount, dtype: object

# %%
transactions['channel'].unique()
# Out:
# array(['Online Banking', 'Mobile App', 'UPI', 'Branch', 'POS', 'ATM'],
#       dtype=object)

# %%
# Most uses transaction channels
most_popular_transaction_channel = transactions['channel'].value_counts()

print("The Most Popular Transaction Channel is:", most_popular_transaction_channel.index[0])
print("Amount is:", most_popular_transaction_channel.iloc[0])
# Out:
# The Most Popular Transaction Channel is: Mobile App
# Amount is: 333776

# %%
transactions.head()
# Out:
#    transaction_id  account_id   txn_date         txn_type    amount  \
# 0               1       42369 2018-03-13          Deposit   1817.91
# 1               2       53934 2022-03-05       Withdrawal  12855.96
# 2               3       53478 2022-05-29          Deposit   8278.61
# 3               4        5270 2024-01-27  Interest Credit  18183.95
# 4               5       85021 2023-01-19        Fee Debit  19658.07
#
#           channel merchant_category trans_month  trans_year
# 0  Online Banking     Salary Credit       March        2018
# 1      Mobile App    ATM Withdrawal       March        2022
# 2             UPI         Education         May        2022
# 3          Branch            Dining     January        2024
# 4             UPI    ATM Withdrawal     January        2023

# %%
# Highest transaction amount
transactions['amount'].idxmax()
# Out:
# 1774037

# %%
# The overall transaction frequency
transactions.shape[0]
# Out:
# 2000000

# %%
# Highest transaction frequency by channel
trans_freq_by_channel = transactions.groupby("channel").size().sort_values(ascending=False)

# %%
print("The Highest Frequency Channel is:", trans_freq_by_channel.index[0])
print("Amount:", trans_freq_by_channel.iloc[0])
# Out:
# The Highest Frequency Channel is: Mobile App
# Amount: 333776

# %%
# Only the highest frequency
highest_frequency = transactions['merchant_category'].value_counts()

print("Highest Transaction:", highest_frequency.iloc[0])
print("Merchant Category:", highest_frequency.index[0])
# Out:
# Highest Transaction: 143377
# Merchant Category: Utilities

# %%
# Detect top 1% highest value transaction
top_1_threshold = transactions['amount'].quantile(0.99)
top_1_transactions = transactions[transactions['amount'] >= top_1_threshold]

print('Top 1% Transactions:', top_1_transactions.shape[0])
# Out:
# Top 1% Transactions: 20000

# %%
# Which branch handle the top 1 transactions
top_1_threshold = transactions['amount'].quantile(0.99)
top_1_transactions = transactions[transactions['amount'] >= top_1_threshold]

# %%
accounts.reset_index(inplace=True)

# %%
top_1_details = top_1_transactions.merge(
    accounts[['account_id', 'branch_id']],
    on = 'account_id',
    how = 'left'
).reset_index()

top_1_details = top_1_details.merge(
    branches[['branch_id', 'branch_name']],
    on = 'branch_id',
    how = 'left'
)

# %%
branch_summary = (
    top_1_details.groupby('branch_name')
    .agg(
        total_transactions = ('transaction_id', 'count'),
        total_amount = ('amount', 'sum')
    )
    .sort_values('total_amount', ascending=False)
)
branch_summary
# Out:
#                     total_transactions  total_amount
# branch_name
# Bhopal Branch 8                    572   19004563.59
# Kochi Branch 2                     554   18544869.84
# Chennai Branch 3                   443   14829475.26
# Pune Branch 1                      418   13988435.53
# Bhopal Branch 5                    409   13896909.73
# ...                                ...           ...
# Delhi Branch 2                     115    3843331.76
# Ahmedabad Branch 3                 116    3815456.22
# Bengaluru Branch 2                 115    3812500.19
# Kochi Branch 6                     114    3796139.48
# Delhi Branch 3                     108    3638370.01
#
# [93 rows x 2 columns]

# %% [markdown]
# ### Card Analysis

# %%
cards.shape
# Out:
# (65000, 8)

# %%
cards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65000 entries, 0 to 64999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   card_id       65000 non-null  int64
#  1   customer_id   65000 non-null  int64
#  2   account_id    65000 non-null  int64
#  3   card_type     65000 non-null  object
#  4   issue_date    65000 non-null  datetime64[ns]
#  5   expiry_date   65000 non-null  datetime64[ns]
#  6   credit_limit  65000 non-null  int64
#  7   status        65000 non-null  object
# dtypes: datetime64[ns](2), int64(4), object(2)
# memory usage: 4.0+ MB

# %%
cards.head()
# Out:
#    card_id  customer_id  account_id         card_type issue_date expiry_date  \
# 0        1        34846       75950     Credit - Gold 2018-12-05  2023-12-04
# 1        2        50151       55880  Credit - Classic 2016-05-19  2021-05-18
# 2        3        11246       86152     Credit - Gold 2023-08-30  2028-08-28
# 3        4        23866       10907  Credit - Classic 2018-07-24  2023-07-23
# 4        5        14097       22455  Credit - Classic 2023-08-16  2028-08-14
#
#    credit_limit  status
# 0             0  Active
# 1             0  Active
# 2         50000  Active
# 3             0  Active
# 4         50000  Active

# %%
cards['card_type'].unique()
# Out:
# array(['Credit - Gold', 'Credit - Classic', 'Debit', 'Credit - Platinum'],
#       dtype=object)

# %%
cards['status'].unique()
# Out:
# array(['Active', 'Expired', 'Blocked'], dtype=object)

# %%
today = pd.Timestamp.today().normalize()

cards['card_status'] = cards['expiry_date'].apply(
    lambda x: 'Expired' if x < today else 'Active'
)

# %%
cards.head()
# Out:
#    card_id  customer_id  account_id         card_type issue_date expiry_date  \
# 0        1        34846       75950     Credit - Gold 2018-12-05  2023-12-04
# 1        2        50151       55880  Credit - Classic 2016-05-19  2021-05-18
# 2        3        11246       86152     Credit - Gold 2023-08-30  2028-08-28
# 3        4        23866       10907  Credit - Classic 2018-07-24  2023-07-23
# 4        5        14097       22455  Credit - Classic 2023-08-16  2028-08-14
#
#    credit_limit  status card_status
# 0             0  Active     Expired
# 1             0  Active     Expired
# 2         50000  Active      Active
# 3             0  Active     Expired
# 4         50000  Active      Active

# %%
cards['card_status'].value_counts()
# Out:
# card_status
# Expired    41185
# Active     23815
# Name: count, dtype: int64

# %%
cards_summary = cards['card_status'].value_counts(normalize=True).mul(100).round(2)
cards_summary
# Out:
# card_status
# Expired    63.36
# Active     36.64
# Name: proportion, dtype: float64

# %%
card_counts = cards['card_status'].value_counts()

fig, ax = plt.subplots(figsize = (10,4))

card_counts.plot(kind = 'bar', ax=ax)

for container in ax.containers:
    ax.bar_label(container, fmt='{:,.0f}')

plt.title('Active Cards VS Expire Cards')
plt.xlabel('Card Status')
plt.ylabel('Cards')
plt.grid(False)
plt.show()

# %%
total_cards = cards['card_type'].value_counts()
total_cards
# Out:
# card_type
# Debit                35700
# Credit - Classic     16300
# Credit - Gold         8367
# Credit - Platinum     4633
# Name: count, dtype: int64

# %%
cards[cards['status'] == 'Blocked'].value_counts()
# Out:
# card_id  customer_id  account_id  card_type          issue_date  expiry_date  credit_limit  status   card_status
# 16       2927         1350        Debit              2018-07-17  2023-07-16   0             Blocked  Expired        1
# 43645    58110        31956       Debit              2023-10-19  2028-10-17   0             Blocked  Active         1
# 43736    42327        66284       Debit              2015-08-28  2020-08-26   0             Blocked  Expired        1
# 43706    41689        69785       Debit              2022-02-15  2027-02-14   100000        Blocked  Active         1
# 43671    27805        22053       Debit              2018-07-04  2023-07-03   0             Blocked  Expired        1
#                                                                                                                    ..
# 21930    39371        14452       Credit - Platinum  2020-12-03  2025-12-02   0             Blocked  Expired        1
# ...

# %%
fig, ax = plt.subplots(figsize = (10,4))

cards_counts = cards['status'].value_counts()

cards_counts.plot(kind = 'line', linewidth = 2, marker = 'o', ax = ax)

for container in ax.containers:
    ax.bar_label(container, fmt='{:,.0f}')

plt.title('Cards Status')
plt.xlabel('Status')
plt.ylabel('Cards')
plt.show()

# %%
cards.head()
# Out:
#    card_id  customer_id  account_id         card_type issue_date expiry_date  \
# 0        1        34846       75950     Credit - Gold 2018-12-05  2023-12-04
# 1        2        50151       55880  Credit - Classic 2016-05-19  2021-05-18
# 2        3        11246       86152     Credit - Gold 2023-08-30  2028-08-28
# 3        4        23866       10907  Credit - Classic 2018-07-24  2023-07-23
# 4        5        14097       22455  Credit - Classic 2023-08-16  2028-08-14
#
#    credit_limit  status card_status
# 0             0  Active     Expired
# 1             0  Active     Expired
# 2         50000  Active      Active
# 3             0  Active     Expired
# 4         50000  Active      Active

# %%
# card montly transactions
transactions.head()
# Out:
#    transaction_id  account_id   txn_date         txn_type    amount  \
# 0               1       42369 2018-03-13          Deposit   1817.91
# 1               2       53934 2022-03-05       Withdrawal  12855.96
# 2               3       53478 2022-05-29          Deposit   8278.61
# 3               4        5270 2024-01-27  Interest Credit  18183.95
# 4               5       85021 2023-01-19        Fee Debit  19658.07
#
#           channel merchant_category trans_month  trans_year
# 0  Online Banking     Salary Credit       March        2018
# 1      Mobile App    ATM Withdrawal       March        2022
# 2             UPI         Education         May        2022
# 3          Branch            Dining     January        2024
# 4             UPI    ATM Withdrawal     January        2023

# %%
#card_transactions = cards.merge(
#    transactions,
#    on = 'account_id',
#    how = 'inner'
#)

# Calculate montly transaction by card type
#monthly_card_type = card_transactions.groupby(['trans_year','trans_month', 'card_type']).agg(
#    total_transactions = ('transaction_id', 'count'),
#    total_amount = ('amount', 'sum'),
#    average_amount = ('amount', 'mean'),
#    averae_transactions = ('transaction_id', 'mean')
#).reset_index().round(2)

# %%
#monthly_card_type.head()

# %% [markdown]
# # Connect to MySQL

# %%
pip install psycopg2-binary sqlalchemy

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = 'root'
host = '127.0.0.1'
port = '3306'
password = quote_plus('Krishna@123')
database = 'banking_transactions'

engine = create_engine(
    f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}'
)

table_name = 'accounts'
accounts.to_sql(table_name, engine, if_exists='replace', index = False)
# Out:
# 95000

# %%
## Export branches table
table_name = 'branches'
branches.to_sql(table_name, engine, if_exists='replace', index = False)

## Export card_transactions
#table_name = 'card_transactions'
#card_transactions.to_sql(table_name, engine, if_exists='replace', index=False)

## cards
table_name = 'cards'
cards.to_sql(table_name, engine, if_exists='replace', index=False)

## customers
table_name = 'customers'
customers.to_sql(table_name, engine, if_exists='replace', index=False)

##  Employees
table_name = 'employees'
emp.to_sql(table_name, engine, if_exists='replace', index=False)

## loans
table_name = 'loans'
loans.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 22000

# %%
## Loan Payments
table_name = 'loan_payments'
loan_payments.to_sql(table_name, engine, if_exists='replace', index=False)

## Support Tickets
table_name = 'support'
support.to_sql(table_name, engine, if_exists='replace', index=False)

## Transactions
table_name = 'transactions'
transactions.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 2000000
